# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# 🍩 Create a circle of dots inside another circle
X_circle, y_circle = make_circles(n_samples=400, factor=0.3, noise=0.05, random_state=42)

# Let's see how it looks
plt.scatter(X_circle[:, 0], X_circle[:, 1], c=y_circle, cmap='cool')
plt.title("🍩 Original Circle Data (2D)")
plt.axis("equal")
plt.grid(True)
plt.show()
# Out:
# c:\Users\yuvra\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127849 (\N{DOUGHNUT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_circle)

# Plot what normal PCA does
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_circle, cmap='cool')
plt.title("😵 PCA on Circular Data")
plt.grid(True)
plt.show()

# %%
from sklearn.decomposition import KernelPCA

kpca = KernelPCA(n_components=2, kernel="rbf", gamma=10)
X_kpca = kpca.fit_transform(X_circle)

# Plot the result
plt.scatter(X_kpca[:, 0], X_kpca[:, 1], c=y_circle, cmap='cool')
plt.title("🔥 Kernel PCA (RBF) - Unrolled Circles")
plt.grid(True)
plt.show()
# Out:
# c:\Users\yuvra\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
